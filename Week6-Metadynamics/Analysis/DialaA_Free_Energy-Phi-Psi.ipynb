# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the COLVAR data
colvar_file = '/home/yhp2008/comp-lab-class-2024/Week6-Metadynamics/Inputs/DialaA/2D/COLVAR2'  # replace with the path to your COLVAR file
data = np.loadtxt(colvar_file, skiprows=1)  # Skip header if necessary


# Assuming the COLVAR file has time in the first column, phi in the second, and psi in the third column
time = data[:, 0]  # First column (in ps)
phi = data[:, 1]   # Second column (phi angle in radians)
psi = data[:, 2]   # Third column (psi angle in radians)

# Convert time to nanoseconds
time_ns = time / 1000  # Convert ps to ns

# Select data for the first 2 ns
mask = time_ns <= 2
time_ns_filtered = time_ns[mask]
phi_filtered = phi[mask]
psi_filtered = psi[mask]

# Plotting
plt.figure(figsize=(12, 8))

# Plot phi
plt.subplot(2, 1, 1)
plt.plot(time_ns_filtered, phi_filtered, label='Phi', color='blue')
plt.xlabel('Time (ns)')
plt.ylabel('Phi (radians)')
plt.title('Time Evolution of Phi Angle')
plt.grid(True)
plt.legend()

# Plot psi
plt.subplot(2, 1, 2)
plt.plot(time_ns_filtered, psi_filtered, label='Psi', color='green')
plt.xlabel('Time (ns)')
plt.ylabel('Psi (radians)')
plt.title('Time Evolution of Psi Angle')
plt.grid(True)
plt.legend()

# Adjust layout and show the plots
plt.tight_layout()
plt.savefig('CV_evolution_phi_psi.png')  # Save the figure
plt.show()  # Show the figure

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the HILLS file
hills_file = '/home/yhp2008/comp-lab-class-2024/Week6-Metadynamics/Inputs/DialaA/2D/HILLS'  # Replace with your HILLS file path
data = np.loadtxt(hills_file, comments='#')

# Extract columns
time = data[:, 0]  # First column: time
height = data[:, 5]  # Fourth column: Gaussian height

# Plotting the Gaussian height over time using dots
plt.figure(figsize=(10, 6))
plt.scatter(time, height, label='Gaussian Height', color='blue', s=10)  # s=10 controls the size of the dots
plt.xlabel('Time (ps)')
plt.ylabel('Gaussian Height (kJ/mol)')
plt.title('Time Evolution of Gaussian Height in Metadynamics')
plt.grid()
plt.legend()
plt.xlim(0, 10000)  # Adjust limits as needed for the first 2 ns
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the COLVAR data (replace with the path to your COLVAR file)
fes_file = '/home/yhp2008/comp-lab-class-2024/Week6-Metadynamics/Inputs/DialaA/2D/fes_0.dat'  # Example path
data = np.loadtxt(fes_file, comments='#')  # Skips comment lines

# Extract phi, psi, and free energy (file.free)
phi = data[:, 0]    # First column (phi)
psi = data[:, 1]    # Second column (psi)
free_energy = data[:, 2]  # Third column (free energy)

# Reshape phi, psi, and free_energy into 2D grids for plotting
nbins_phi = 33  # As specified in your file
nbins_psi = 18  # As specified in your file

# Create the grid for phi and psi
phi_edges = np.linspace(-np.pi, np.pi, nbins_phi)
psi_edges = np.linspace(-np.pi, np.pi, nbins_psi)

# Create a 2D histogram for free energy
H, xedges, yedges = np.histogram2d(phi, psi, bins=[phi_edges, psi_edges], weights=free_energy)

# Normalize the free energy by subtracting the minimum value (to shift it to zero)
H = H - np.nanmin(H)

# Plot the Free Energy Surface (FES)
plt.figure(figsize=(8, 6))
plt.imshow(H.T, origin='lower', extent=[-np.pi, np.pi, -np.pi, np.pi], aspect='auto', cmap='viridis')
plt.colorbar(label='Free Energy (a.u.)')
plt.xlabel('Phi (radians)')
plt.ylabel('Psi (radians)')
plt.title('Free Energy Surface (FES) vs Phi and Psi')
plt.grid(False)
plt.tight_layout()

# Save the plot
plt.savefig('FES_vs_Phi_Psi.png')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import animation
import numpy as np

def load_data(filename):
  """Loads data from the specified file."""
  data = []
  with open(filename, "r") as f:
    # Skip header lines containing `#!`
    for line in f:
      if not line.startswith("#!"):
        phi, psi, free_energy = map(float, line.strip().split())
        data.append((phi, psi, free_energy))
  return np.array(data)

def plot_free_energy(data, timestep):
  """Plots the free energy as a function of phi and psi."""
  phi, psi, free_energy = data.T
  fig, ax = plt.subplots()
  ax.contourf(phi, psi, free_energy, cmap="inferno")
  ax.set_xlabel("phi")
  ax.set_ylabel("psi")
  ax.set_title(f"Free Energy - Timestep: {timestep}")
  return fig, ax

def create_animation(filenames, interval=100):
  """Creates an animation showing the free energy evolution."""
  fig, ax = plt.subplots()
  frames = []
  for i, filename in enumerate(filenames):
    data = load_data(filename)
    frame_fig, frame_ax = plot_free_energy(data, i)
    frames.append(frame_fig)
  anim = animation.ArtistAnimation(
      fig, frames, interval=interval, blit=True, repeat=False
  )
  anim.save("free_energy_evolution.gif", fps=10, dpi=300)

# Example usage
filenames = [f"/home/yhp2008/comp-lab-class-2024/Week6-Metadynamics/Inputs/DialaA/2D/fes_{i}.dat" for i in range(100)]  # Assuming filenames are from 0 to 99
create_animation(filenames)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 41
#      39 # Example usage
#      40 filenames = [f"/home/yhp2008/comp-lab-class-2024/Week6-Metadynamics/Inputs/DialaA/2D/fes_{i}.dat" for i in range(100)]  # Assuming filenames are from 0 to 99
# ---> 41 create_animation(filenames)
#
# Cell In[14], line 31, in create_animation(filenames, interval)
#      29 frames = []
#      30 for i, filename in enumerate(filenames):
# ---> 31   data = load_data(filename)
#      32   frame_fig, frame_ax = plot_free_energy(data, i)
#      33   frames.append(frame_fig)
#
# Cell In[14], line 12, in load_data(filename)
#      10   for line in f:
#      11     if not line.startswith("#!"):
# ---> 12       phi, psi, free_energy = map(float, line.strip().split())
#      13       data.append((phi, psi, free_energy))
#      14 return np.array(data)
#
# ValueError: too many values to unpack (expected 3)

# %%
import matplotlib.pyplot as plt
from matplotlib import animation
import numpy as np

def load_data(filename):
  """Loads data from the specified file."""
  data = []
  with open(filename, "r") as f:
    # Skip header lines containing `#!`
    for line in f:
      if not line.startswith("#!"):
        phi, psi, free_energy = map(float, line.strip().split())
        data.append((phi, psi, free_energy))
  return np.array(data)

def plot_free_energy(data, timestep):
  """Plots the free energy as a function of phi and psi."""
  phi, psi, free_energy = data.T
  fig, ax = plt.subplots()
  ax.contourf(phi, psi, free_energy, cmap="inferno")
  ax.set_xlabel("phi")
  ax.set_ylabel("psi")
  ax.set_title(f"Free Energy - Timestep: {timestep}")
  return fig, ax

def create_animation(filenames, interval=100):
  """Creates an animation showing the free energy evolution."""
  fig, ax = plt.subplots()
  frames = []
  for i, filename in enumerate(filenames):
    data = load_data(filename)
    frame_fig, frame_ax = plot_free_energy(data, i)
    frames.append(frame_fig)
  anim = animation.ArtistAnimation(
      fig, frames, interval=interval, blit=True, repeat=False
  )
  anim.save("free_energy_evolution.gif", fps=10, dpi=300)

# Example usage
filenames = [f"/home/yhp2008/comp-lab-class-2024/Week6-Metadynamics/Inputs/DialaA/2D/fes_{i}.dat" for i in range(100)]  # Assuming filenames are from 0 to 99
create_animation(filenames)
